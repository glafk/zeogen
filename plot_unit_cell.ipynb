# %%
import torch
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Example tensor with 3D coordinates
tensor = torch.tensor([[ 1.0701,  6.6834, 10.5126],
        [14.2130,  0.8099,  5.4972],
        [ 7.7549, 14.2579,  1.8933],
        [37.7652,  7.8286, 18.8475],
        [13.7509,  1.4665, 22.9514],
        [24.2443,  0.5824,  6.6704],
        [32.2729, 13.7898,  2.1971],
        [25.5768, 37.1303, 23.3348],
        [ 8.2532, 36.0719, 10.7449],
        [ 1.9605, 13.6048,  5.5391],
        [14.8961,  7.5501, 26.3794],
        [ 7.7642,  0.6450, 15.3516],
        [ 0.9563, 14.2575, 21.5323],
        [ 1.4788, 23.5741,  4.9271],
        [16.2802, 31.7661, 27.1424],
        [ 1.9549, 23.8182, 22.2465],
        [ 2.0459, 31.1320, 16.9935],
        [34.3966, 23.6237, 28.0338],
        [ 2.0635, 29.8451,  9.8784],
        [ 8.1514, 24.3831, 26.0903],
        [31.4638,  0.9208, 17.9037],
        [24.6836, 29.8919, 27.7120],
        [30.8486,  0.3666, 12.1459],
        [22.9400,  6.5792, 26.8125]])

# Extract x, y, z coordinates
x = tensor[:, 0].numpy()
y = tensor[:, 1].numpy()
z = tensor[:, 2].numpy()

# Create a 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plot the points
ax.scatter(x, y, z, c='r', marker='o')

# Add integer labels to each point
for i in range(len(x)):
    ax.text(x[i], y[i], z[i], f'{i}', color='blue', fontsize=12)

# Set labels
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

# Show the plot
plt.show()
