# %%
import pickle

with open("zds_inspection.pickle", "rb") as f:
    data = pickle.load(f)

print(len(data))
print(data[0])
# Out:
# 18
# {'pred_domains': tensor([[ -0.4313,   0.3162,  -7.5427,  -7.5821,  -8.8638,  -7.6553,  -7.8056,
#           -8.1117,  -8.2397,  -9.3216, -10.0829,  -9.5135,  -9.2914,  -8.9837,
#          -10.2798,  -7.2128,  -7.9967,  -6.0351,  -8.7124,  -7.0492,  -8.7588,
#           -8.0574,  -7.2572,  -9.2611,  -7.7870,  -7.9267,   0.4829],
#         [ -0.4236,   0.3306,  -7.7572,  -7.7447,  -8.6632,  -7.1058,  -7.2281,
#           -7.8075,  -7.6478,  -9.1660,  -9.8257,  -9.2551,  -9.1564,  -8.8601,
#          -10.1308,  -7.2574,  -7.7966,  -5.3610,  -8.2929,  -6.5796,  -8.6203,
#           -8.1630,  -6.8027,  -9.1524,  -7.9382,  -7.3434,   0.4991],
#         [ -0.3690,   0.3668,  -6.6506,  -6.6234,  -8.3973,  -6.5106,  -6.6936,
#           -7.0115,  -8.3214,  -9.0675, -10.1274,  -9.4506,  -9.2296,  -8.9381,
#          -10.1334,  -5.9939,  -7.7482,  -4.9384,  -8.5753,  -6.2175,  -8.2682,
#           -7.1367,  -7.5701,  -9.0070,  -6.6588,  -7.1508,   0.5257],
# ...
