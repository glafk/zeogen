# %% [markdown]
# # Models

# %% [markdown]
# * CDVAE - baseline
# * CDVAE with HOA conditioning through prior
# * CDVAE with HOA conditioning through MLP
# * CDVAE with prior just for topologies
# * DIVA with topologies and types(HOA) decoder
# * DIVA with GemNet decoder only for topologies and CRF layer for types???
# * DIVA with decoder only for topologies and independent sampling for atom types

# %% [markdown]
# # Experiments
#
# * Include previous experiments
# * Run experiments with balanced batching and variance clamping on all models above with several datasets

# %% [markdown]
# # Datasets
#
# * Zeolites < 50 atoms from small (19 types) dataset
# * Zeolites < 50 atoms from large dataset
#
# if these two can be optimized in a stable manner
#
# * all from small dataset
# * all from large dataset
