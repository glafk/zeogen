# %%
import pickle

with open("combined_train.pickle", 'rb') as f:
    data = pickle.load(f)

# %%
print(type(data))
# Out:
# <class 'list'>

# %%
print(data[0])
# Out:
# {'frac_coords': array([[0.728, 0.054, 0.07 ],
#        [0.131, 0.262, 0.107],
#        [0.2  , 0.4  , 0.172],
#        [0.119, 0.237, 0.231],
#        [0.226, 0.   , 0.   ],
#        [0.   , 0.   , 0.196],
#        [0.   , 0.   , 0.117],
#        [0.946, 0.674, 0.07 ],
#        [0.738, 0.869, 0.107],
#        [0.6  , 0.8  , 0.172],
#        [0.763, 0.881, 0.231],
#        [0.   , 0.226, 0.   ],
#        [0.326, 0.272, 0.07 ],
#        [0.131, 0.869, 0.107],
#        [0.2  , 0.8  , 0.172],
#        [0.119, 0.881, 0.231],
#        [0.774, 0.774, 0.   ],
#        [0.054, 0.728, 0.93 ],
#        [0.262, 0.131, 0.892],
#        [0.4  , 0.2  , 0.828],
#        [0.237, 0.119, 0.769],
#        [0.   , 0.   , 0.804],
#        [0.   , 0.   , 0.883],
#        [0.272, 0.326, 0.93 ],
#        [0.869, 0.131, 0.892],
#        [0.8  , 0.2  , 0.828],
#        [0.881, 0.119, 0.769],
#        [0.674, 0.946, 0.93 ],
#        [0.869, 0.738, 0.892],
#        [0.8  , 0.6  , 0.828],
# ...

# %%
zeolite_lengths = {item["zeolite_code"]: len(item["frac_coords"]) for item in data}

# %%
sorted_dict = dict(sorted(zeolite_lengths.items(), key=lambda item: item[1]))
print(sorted_dict)
# Out:
# {'NAT': 20, 'ITW': 24, 'TON': 24, 'TON2': 24, 'TON3': 24, 'TON4': 24, 'TONch': 24, 'LTA': 24, 'MTW': 28, 'BEC': 32, 'MER': 32, 'CHA': 36, 'ERI': 36, 'FER': 36, 'HEU': 36, 'LTL': 36, 'MOR': 48, 'RHO': 48, 'MEL': 96, 'MELch': 96, 'MFI': 96, 'DDR': 120, 'DDRch1': 120, 'DDRch2': 120, 'YFI': 120, 'FAU': 192, 'FAUch': 192}

# %%
for code in set(zeolite_codes):
    print(f"Count of {code}: {zeolite_codes.count(code)}")

print(f"Total: {len(data)}")
# Out:
# Count of TON2: 84
# Count of HEU: 492
# Count of DDR: 514
# Count of FAUch: 475
# Count of MTW: 490
# Count of ITW: 790
# Count of MELch: 215
# Count of TON: 90
# Count of CHA: 492
# Count of LTA: 499
# Count of YFI: 471
# Count of MEL: 396
# Count of MER: 486
# Count of RHO: 725
# Count of FER: 492
# Count of TONch: 77
# Count of DDRch2: 309
# Count of MFI: 2205
# Count of TON3: 183
# Count of DDRch1: 159
# Count of MOR: 3000
# Count of LTL: 492
# Count of ERI: 492
# Count of FAU: 709
# Count of NAT: 498
# Count of BEC: 486
# Count of TON4: 186
# Total: 15507

# %%
print(zeolite_codes.count("MOR"))
print(zeolite_codes.count("RHO"))
print(zeolite_codes.count("MFI"))
# Out:
# 3000
# 725
# 2205

# %%
MORs = [item for item in data if item["zeolite_code"] == "MOR"]
RHOs = [item for item in data if item["zeolite_code"] == "RHO"]
MFIs = [item for item in data if item["zeolite_code"] == "MFI"]

# %%
MFIs[0]
# Out:
# {'frac_coords': array([[0.421, 0.071, 0.69 ],
#         [0.326, 0.034, 0.85 ],
#         [0.279, 0.054, 0.066],
#         [0.125, 0.051, 0.048],
#         [0.072, 0.036, 0.823],
#         [0.203, 0.069, 0.72 ],
#         [0.419, 0.827, 0.68 ],
#         [0.315, 0.876, 0.836],
#         [0.273, 0.828, 0.04 ],
#         [0.118, 0.828, 0.018],
#         [0.066, 0.879, 0.809],
#         [0.195, 0.829, 0.709],
#         [0.079, 0.929, 0.19 ],
#         [0.174, 0.966, 0.35 ],
#         [0.221, 0.946, 0.566],
#         [0.375, 0.949, 0.548],
#         [0.428, 0.964, 0.323],
#         [0.297, 0.931, 0.22 ],
#         [0.081, 0.173, 0.18 ],
#         [0.185, 0.123, 0.336],
#         [0.227, 0.172, 0.54 ],
#         [0.382, 0.172, 0.518],
#         [0.434, 0.121, 0.309],
#         [0.305, 0.171, 0.209],
#         [0.921, 0.429, 0.81 ],
#         [0.826, 0.466, 0.65 ],
#         [0.779, 0.446, 0.434],
#         [0.625, 0.449, 0.452],
#         [0.572, 0.464, 0.677],
# ...
