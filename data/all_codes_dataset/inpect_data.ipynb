# %%
import pickle

with open("combined_train.pickle", 'rb') as f:
    data = pickle.load(f)

# %%
print(len(data))
# Out:
# 18845

# %%
print(data[0])
# Out:
# {'frac_coords': [[0.156, 0.156, 0.156], [0.656, 0.656, 0.656], [0.156, 0.156, 0.844], [0.656, 0.656, 0.344], [0.844, 0.156, 0.156], [0.344, 0.656, 0.656], [0.844, 0.156, 0.844], [0.344, 0.656, 0.344], [0.156, 0.844, 0.156], [0.656, 0.344, 0.656], [0.156, 0.844, 0.844], [0.656, 0.344, 0.344], [0.844, 0.844, 0.844], [0.344, 0.344, 0.344], [0.844, 0.844, 0.156], [0.344, 0.344, 0.656]], 'atom_types': [14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 13, 13, 13, 14, 13], 'lengths': [9.905, 9.905, 9.905], 'angles': [90.0, 90.0, 90.0], 'hoa': 38.3377, 'zeolite_code': 'ACO'}

# %%
zeolite_lengths = {item["zeolite_code"]: len(item["frac_coords"]) for item in data} 
print(zeolite_lengths)
# Out:
# {'ACO': 16, 'AEI': 48, 'AEL': 40, 'AEN': 48, 'AET': 72, 'AFG': 48, 'AFI': 24, 'AFN': 32, 'AFO': 40, 'AFR': 32, 'AFS': 56, 'AFT': 72, 'AFV': 30, 'AFX': 48, 'AFY': 16, 'AHT': 24, 'ANO': 96, 'APC': 32, 'APD': 32, 'AST': 40, 'ASV': 20, 'ATN': 16, 'ATO': 36, 'ATS': 24, 'ATT': 12, 'ATV': 24, 'AVE': 144, 'AVL': 42, 'AWO': 48, 'AWW': 24, 'BCT': 8, 'BIK': 12, 'BOF': 24, 'BOG': 96, 'BOZ': 92, 'BPH': 28, 'BRE': 16, 'BSV': 96, 'CAN': 12, 'CAS': 24, 'CDO': 36, 'CFI': 32, 'CGF': 36, 'CGS': 32, 'CON': 56, 'CSV': 20, 'CZP': 24, 'DAC': 24, 'DFO': 132, 'DFT': 8, 'DOH': 34, 'DON': 64, 'EAB': 36, 'EEI': 200, 'EMT': 96, 'EON': 60, 'EOS': 12, 'EPI': 24, 'ESV': 48, 'ETL': 72, 'ETR': 48, 'ETV': 14, 'EUO': 112, 'EWF': 116, 'EWO': 24, 'EWS': 96, 'EZT': 48, 'FAR': 84, 'FRA': 60, 'GIS': 16, 'GIU': 96, 'GME': 24, 'GON': 32, 'GOO': 32, 'IFO': 32, 'IFR': 32, 'IFW': 64, 'IFY': 48, 'IHW': 112, 'IRN': 92, 'IRR': 52, 'ISV': 64, 'ITE': 64, 'ITG': 56, 'ITH': 56, 'ITR': 112, 'ITT': 46, 'ITW': 24, 'IWR': 56, 'IWS': 136, 'IWV': 152, 'IWW': 112, 'JNT': 32, 'JOZ': 20, 'JRY': 24, 'JSN': 16, 'JSR': 96, 'JST': 48, 'JSW': 48, 'JSY': 60, 'JZT': 80, 'KFI': 96, 'LAU': 24, 'LEV': 54, 'LIO': 36, 'LOS': 24, 'LOV': 18, 'LTF': 108, 'LTJ': 16, 'MAR': 72, 'MAZ': 36, 'MEI': 34, 'MEP': 46, 'MFS': 36, 'MON': 16, 'MOZ': 108, 'MRT': 24, 'MSE': 112, 'MSO': 90, 'MTF': 44, 'MTN': 136, 'MTT': 24, 'MVY': 12, 'MWW': 72, 'NAB': 10, 'NES': 136, 'NON': 88, 'NPT': 36, 'NSI': 12, 'OBW': 76, 'OFF': 18, 'OKO': 68, 'OSI': 32, 'OSO': 9, 'OWE': 16, 'PCR': 60, 'PHI': 32, 'PON': 24, 'POR': 64, 'POS': 64, 'PSI': 144, 'PTF': 80, 'PTO': 48, 'PTT': 24, 'PTY': 10, 'PWW': 40, 'RFE': 48, 'RRO': 18, 'RTE': 24, 'RTH': 32, 'RUT': 36, 'RWR': 32, 'RWY': 48, 'SAF': 64, 'SAO': 56, 'SAS': 32, 'SAT': 72, 'SAV': 48, 'SBE': 128, 'SBN': 10, 'SBS': 96, 'SBT': 144, 'SEW': 66, 'SFE': 14, 'SFF': 32, 'SFG': 74, 'SFH': 64, 'SFN': 32, 'SFO': 32, 'SFS': 56, 'SFW': 108, 'SGT': 64, 'SIV': 64, 'SOD': 12, 'SOF': 40, 'SOR': 48, 'SOS': 24, 'SOV': 128, 'SSF': 54, 'SSY': 28, 'STF': 32, 'STI': 72, 'STT': 64, 'STW': 60, 'SVV': 56, 'SWY': 72, 'SZR': 36, 'TER': 80, 'THO': 10, 'TOL': 72, 'TUN': 192, 'UEI': 48, 'UFI': 64, 'UOS': 24, 'UOV': 176, 'UOZ': 40, 'USI': 40, 'UTL': 76, 'UWY': 60, 'VET': 17, 'VFI': 36, 'VNI': 60, 'VSV': 36, 'WEI': 20, 'YUG': 16, 'ZON': 32}

# %%
sorted_dict = dict(sorted(zeolite_codes.items(), key=lambda item: item[1]))
print(sorted_dict)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 sorted_dict = dict(sorted(zeolite_codes.items(), key=lambda item: item[1]))
#       2 print(sorted_dict)
#
# NameError: name 'zeolite_codes' is not defined

# %%
for code in set(zeolite_codes):
    print(f"Count of {code}: {zeolite_codes.count(code)}")

print(f"Total: {len(data)}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 2
#       1 for code in set(zeolite_codes):
# ----> 2     print(f"Count of {code}: {zeolite_codes.count(code)}")
#       4 print(f"Total: {len(data)}")
#
# AttributeError: 'dict' object has no attribute 'count'

# %%
print(zeolite_codes.count("MOR"))
print(zeolite_codes.count("RHO"))
print(zeolite_codes.count("MFI"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 print(zeolite_codes.count("MOR"))
#       2 print(zeolite_codes.count("RHO"))
#       3 print(zeolite_codes.count("MFI"))
#
# NameError: name 'zeolite_codes' is not defined

# %%
MORs = [item for item in data if item["zeolite_code"] == "MOR"]
RHOs = [item for item in data if item["zeolite_code"] == "RHO"]
MFIs = [item for item in data if item["zeolite_code"] == "MFI"]

# %%
MFIs[0]
# Out:
# {'frac_coords': array([[0.421, 0.071, 0.69 ],
#         [0.326, 0.034, 0.85 ],
#         [0.279, 0.054, 0.066],
#         [0.125, 0.051, 0.048],
#         [0.072, 0.036, 0.823],
#         [0.203, 0.069, 0.72 ],
#         [0.419, 0.827, 0.68 ],
#         [0.315, 0.876, 0.836],
#         [0.273, 0.828, 0.04 ],
#         [0.118, 0.828, 0.018],
#         [0.066, 0.879, 0.809],
#         [0.195, 0.829, 0.709],
#         [0.079, 0.929, 0.19 ],
#         [0.174, 0.966, 0.35 ],
#         [0.221, 0.946, 0.566],
#         [0.375, 0.949, 0.548],
#         [0.428, 0.964, 0.323],
#         [0.297, 0.931, 0.22 ],
#         [0.081, 0.173, 0.18 ],
#         [0.185, 0.123, 0.336],
#         [0.227, 0.172, 0.54 ],
#         [0.382, 0.172, 0.518],
#         [0.434, 0.121, 0.309],
#         [0.305, 0.171, 0.209],
#         [0.921, 0.429, 0.81 ],
#         [0.826, 0.466, 0.65 ],
#         [0.779, 0.446, 0.434],
#         [0.625, 0.449, 0.452],
#         [0.572, 0.464, 0.677],
#         [0.703, 0.431, 0.78 ],
#         [0.919, 0.673, 0.82 ],
#         [0.815, 0.624, 0.664],
#         [0.773, 0.672, 0.46 ],
#         [0.619, 0.672, 0.482],
#         [0.566, 0.621, 0.691],
#         [0.695, 0.671, 0.791],
#         [0.579, 0.571, 0.31 ],
#         [0.674, 0.534, 0.15 ],
#         [0.721, 0.554, 0.934],
#         [0.875, 0.551, 0.952],
#         [0.928, 0.536, 0.177],
#         [0.797, 0.569, 0.28 ],
#         [0.581, 0.327, 0.32 ],
#         [0.685, 0.377, 0.164],
#         [0.727, 0.328, 0.96 ],
#         [0.881, 0.328, 0.982],
#         [0.934, 0.379, 0.191],
#         [0.805, 0.329, 0.291],
#         [0.579, 0.929, 0.31 ],
#         [0.674, 0.966, 0.15 ],
#         [0.721, 0.946, 0.934],
#         [0.875, 0.949, 0.952],
#         [0.928, 0.964, 0.177],
#         [0.797, 0.931, 0.28 ],
#         [0.581, 0.173, 0.32 ],
#         [0.685, 0.123, 0.164],
#         [0.727, 0.172, 0.96 ],
#         [0.881, 0.172, 0.982],
#         [0.934, 0.121, 0.191],
#         [0.805, 0.171, 0.291],
#         [0.921, 0.071, 0.81 ],
#         [0.826, 0.034, 0.65 ],
#         [0.779, 0.054, 0.434],
#         [0.625, 0.051, 0.452],
#         [0.572, 0.036, 0.677],
#         [0.703, 0.069, 0.78 ],
#         [0.919, 0.827, 0.82 ],
#         [0.815, 0.876, 0.664],
#         [0.773, 0.828, 0.46 ],
#         [0.619, 0.828, 0.482],
#         [0.566, 0.879, 0.691],
#         [0.695, 0.829, 0.791],
#         [0.079, 0.571, 0.19 ],
#         [0.174, 0.534, 0.35 ],
#         [0.221, 0.554, 0.566],
#         [0.375, 0.551, 0.548],
#         [0.428, 0.536, 0.323],
#         [0.297, 0.569, 0.22 ],
#         [0.081, 0.327, 0.18 ],
#         [0.185, 0.377, 0.336],
#         [0.227, 0.328, 0.54 ],
#         [0.382, 0.328, 0.518],
#         [0.434, 0.379, 0.309],
#         [0.305, 0.329, 0.209],
#         [0.421, 0.429, 0.69 ],
#         [0.326, 0.466, 0.85 ],
#         [0.279, 0.446, 0.066],
#         [0.125, 0.449, 0.048],
#         [0.072, 0.464, 0.823],
#         [0.203, 0.431, 0.72 ],
#         [0.419, 0.673, 0.68 ],
#         [0.315, 0.624, 0.836],
#         [0.273, 0.672, 0.04 ],
#         [0.118, 0.672, 0.018],
#         [0.066, 0.621, 0.809],
#         [0.195, 0.671, 0.709]]),
#  'atom_types': array([14., 14., 14., 14., 14., 14., 14., 14., 14., 14., 14., 14., 14.,
#         14., 14., 14., 14., 14., 13., 14., 14., 14., 14., 14., 13., 14.,
#         14., 14., 14., 14., 14., 14., 14., 14., 14., 14., 14., 14., 14.,
#         14., 14., 14., 14., 14., 13., 13., 13., 14., 14., 14., 14., 14.,
#         13., 14., 14., 13., 13., 13., 13., 14., 13., 14., 14., 14., 14.,
#         13., 14., 14., 14., 14., 14., 14., 14., 14., 14., 14., 14., 14.,
#         14., 14., 14., 14., 14., 14., 14., 14., 14., 14., 14., 14., 14.,
#         14., 14., 14., 14., 14.]),
#  'lengths': [18.256, 20.534, 7.542],
#  'angles': [90, 90, 90],
#  'hoa': 56.6302,
#  'zeolite_code': 'MFI'}

# %%
zeo_codes = [item["zeolite_code"] for item in data]

# %%
zeo_codes
# Out:
# ['DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'DDR',
#  'FAU',
#  'FAU',
#  'FAU',
#  'FAU',
#  'FAU',
#  'FAU',
#  'FAU',
#  'FAU',
#  'FAU',
#  'FAU',
#  'FAU',
#  'FAU',
#  'FAU',
#  'FAU',
#  'FAU',
#  'FAU',
#  'FAU',
#  'FAU',
#  ...]

# %%
zeo_codes_unique = set(zeo_codes)
for code in zeo_codes_unique:
    print(f"Count of {code}: {zeo_codes.count(code)}")

print(len(zeo_codes_unique))
# Out:
# Count of IWW: 66
# Count of AFO: 88
# Count of OWE: 98
# Count of EAB: 94
# Count of AFG: 88
# Count of PTO: 88
# Count of SBE: 76
# Count of SAO: 81
# Count of EON: 87
# Count of ATO: 94
# Count of YUG: 98
# Count of UEI: 88
# Count of SFS: 81
# Count of AVL: 88
# Count of ATT: 103
# Count of ESV: 88
# Count of SAT: 73
# Count of SSY: 96
# Count of APD: 96
# Count of BOZ: 94
# Count of VET: 98
# Count of CSV: 97
# Count of SVV: 81
# Count of UFI: 93
# Count of MTT: 100
# Count of SFH: 93
# Count of RWY: 88
# Count of UOS: 100
# Count of OSO: 106
# Count of NSI: 103
# Count of IFW: 93
# Count of VFI: 94
# Count of SOR: 88
# Count of CAN: 103
# Count of CFI: 96
# Count of EUO: 67
# Count of CDO: 94
# Count of SFN: 96
# Count of SOS: 100
# Count of EPI: 100
# Count of LIO: 94
# Count of GIS: 98
# Count of CON: 81
# Count of ETR: 88
# Count of GIU: 100
# Count of MSO: 91
# Count of OKO: 89
# Count of RTE: 100
# Count of SGT: 92
# Count of FRA: 87
# Count of LAU: 100
# Count of MRT: 100
# Count of SFE: 103
# Count of SAF: 93
# Count of PTY: 106
# Count of BRE: 98
# Count of BCT: 106
# Count of JNT: 96
# Count of IWS: 79
# Count of ATS: 100
# Count of MFS: 94
# Count of RFE: 88
# Count of IFY: 88
# Count of APC: 96
# Count of UWY: 87
# Count of GON: 96
# Count of ITW: 100
# Count of PHI: 96
# Count of JSW: 88
# Count of AFS: 81
# Count of PTT: 100
# Count of AFT: 74
# Count of AFN: 96
# Count of NON: 89
# Count of SFF: 96
# Count of SFW: 63
# Count of AFY: 98
# Count of SZR: 94
# Count of AHT: 100
# Count of OSI: 96
# Count of IFR: 96
# Count of RRO: 98
# Count of DON: 93
# Count of AWO: 88
# Count of JRY: 100
# Count of SIV: 93
# Count of DFT: 106
# Count of AFI: 99
# Count of BIK: 103
# Count of STF: 96
# Count of STI: 73
# Count of FAR: 86
# Count of LEV: 96
# Count of AWW: 100
# Count of ITE: 92
# Count of EMT: 98
# Count of PCR: 87
# Count of DOH: 96
# Count of ISV: 93
# Count of POR: 93
# Count of GOO: 96
# Count of MSE: 66
# Count of SAS: 96
# Count of AFR: 96
# Count of AFX: 88
# Count of EEI: 94
# Count of GME: 100
# Count of ITR: 66
# Count of LTJ: 98
# Count of ATV: 100
# Count of CGS: 96
# Count of ITH: 81
# Count of SAV: 88
# Count of SFG: 74
# Count of UTL: 78
# Count of TER: 82
# Count of EWS: 99
# Count of RTH: 96
# Count of JSY: 87
# Count of IRR: 96
# Count of LOV: 98
# Count of MVY: 103
# Count of MAR: 74
# Count of PSI: 85
# Count of SOV: 75
# Count of MTN: 79
# Count of BOG: 99
# Count of DFO: 79
# Count of JST: 88
# Count of JSN: 98
# Count of MEI: 96
# Count of OBW: 77
# Count of NAB: 106
# Count of THO: 106
# Count of SWY: 73
# Count of AET: 74
# Count of UOZ: 88
# Count of NPT: 94
# Count of AST: 88
# Count of SBT: 84
# Count of IWV: 86
# Count of JOZ: 97
# Count of ANO: 100
# Count of MEP: 98
# Count of PWW: 88
# Count of IFO: 96
# Count of ACO: 98
# Count of AEL: 88
# Count of ZON: 96
# Count of BOF: 100
# Count of RWR: 96
# Count of RUT: 94
# Count of BPH: 96
# Count of MOZ: 64
# Count of CAS: 100
# Count of ITT: 98
# Count of ETV: 103
# Count of SBN: 106
# Count of TOL: 74
# Count of VSV: 94
# Count of ATN: 98
# Count of TUN: 91
# Count of WEI: 97
# Count of KFI: 100
# Count of DAC: 100
# Count of IHW: 66
# Count of SEW: 93
# Count of STW: 87
# Count of PTF: 82
# Count of LOS: 100
# Count of IWR: 81
# Count of EWF: 67
# Count of OFF: 98
# Count of AFV: 96
# Count of NES: 78
# Count of SFO: 96
# Count of IRN: 94
# Count of PON: 100
# Count of SBS: 99
# Count of VNI: 87
# Count of ETL: 73
# Count of LTF: 62
# Count of ITG: 81
# Count of MON: 98
# Count of JZT: 82
# Count of EWO: 100
# Count of JSR: 100
# Count of SSF: 96
# Count of POS: 93
# Count of SOF: 88
# Count of USI: 88
# Count of AEN: 88
# Count of EZT: 88
# Count of MAZ: 94
# Count of MWW: 72
# Count of STT: 93
# Count of UOV: 99
# Count of AEI: 88
# Count of EOS: 103
# Count of ASV: 97
# Count of SOD: 103
# Count of CGF: 94
# Count of BSV: 99
# Count of AVE: 83
# Count of MTF: 98
# Count of CZP: 100
# 206

# %%
sorted_list = sorted(list(zeo_codes_unique))

# %%
sorted_list
# Out:
# ['ACO',
#  'AEI',
#  'AEL',
#  'AEN',
#  'AET',
#  'AFG',
#  'AFI',
#  'AFN',
#  'AFO',
#  'AFR',
#  'AFS',
#  'AFT',
#  'AFV',
#  'AFX',
#  'AFY',
#  'AHT',
#  'ANO',
#  'APC',
#  'APD',
#  'AST',
#  'ASV',
#  'ATN',
#  'ATO',
#  'ATS',
#  'ATT',
#  'ATV',
#  'AVE',
#  'AVL',
#  'AWO',
#  'AWW',
#  'BCT',
#  'BIK',
#  'BOF',
#  'BOG',
#  'BOZ',
#  'BPH',
#  'BRE',
#  'BSV',
#  'CAN',
#  'CAS',
#  'CDO',
#  'CFI',
#  'CGF',
#  'CGS',
#  'CON',
#  'CSV',
#  'CZP',
#  'DAC',
#  'DFO',
#  'DFT',
#  'DOH',
#  'DON',
#  'EAB',
#  'EEI',
#  'EMT',
#  'EON',
#  'EOS',
#  'EPI',
#  'ESV',
#  'ETL',
#  'ETR',
#  'ETV',
#  'EUO',
#  'EWF',
#  'EWO',
#  'EWS',
#  'EZT',
#  'FAR',
#  'FRA',
#  'GIS',
#  'GIU',
#  'GME',
#  'GON',
#  'GOO',
#  'IFO',
#  'IFR',
#  'IFW',
#  'IFY',
#  'IHW',
#  'IRN',
#  'IRR',
#  'ISV',
#  'ITE',
#  'ITG',
#  'ITH',
#  'ITR',
#  'ITT',
#  'ITW',
#  'IWR',
#  'IWS',
#  'IWV',
#  'IWW',
#  'JNT',
#  'JOZ',
#  'JRY',
#  'JSN',
#  'JSR',
#  'JST',
#  'JSW',
#  'JSY',
#  'JZT',
#  'KFI',
#  'LAU',
#  'LEV',
#  'LIO',
#  'LOS',
#  'LOV',
#  'LTF',
#  'LTJ',
#  'MAR',
#  'MAZ',
#  'MEI',
#  'MEP',
#  'MFS',
#  'MON',
#  'MOZ',
#  'MRT',
#  'MSE',
#  'MSO',
#  'MTF',
#  'MTN',
#  'MTT',
#  'MVY',
#  'MWW',
#  'NAB',
#  'NES',
#  'NON',
#  'NPT',
#  'NSI',
#  'OBW',
#  'OFF',
#  'OKO',
#  'OSI',
#  'OSO',
#  'OWE',
#  'PCR',
#  'PHI',
#  'PON',
#  'POR',
#  'POS',
#  'PSI',
#  'PTF',
#  'PTO',
#  'PTT',
#  'PTY',
#  'PWW',
#  'RFE',
#  'RRO',
#  'RTE',
#  'RTH',
#  'RUT',
#  'RWR',
#  'RWY',
#  'SAF',
#  'SAO',
#  'SAS',
#  'SAT',
#  'SAV',
#  'SBE',
#  'SBN',
#  'SBS',
#  'SBT',
#  'SEW',
#  'SFE',
#  'SFF',
#  'SFG',
#  'SFH',
#  'SFN',
#  'SFO',
#  'SFS',
#  'SFW',
#  'SGT',
#  'SIV',
#  'SOD',
#  'SOF',
#  'SOR',
#  'SOS',
#  'SOV',
#  'SSF',
#  'SSY',
#  'STF',
#  'STI',
#  'STT',
#  'STW',
#  'SVV',
#  'SWY',
#  'SZR',
#  'TER',
#  'THO',
#  'TOL',
#  'TUN',
#  'UEI',
#  'UFI',
#  'UOS',
#  'UOV',
#  'UOZ',
#  'USI',
#  'UTL',
#  'UWY',
#  'VET',
#  'VFI',
#  'VNI',
#  'VSV',
#  'WEI',
#  'YUG',
#  'ZON']

# %%
mapped_dict = {code: number for code, number in zip(sorted_list, range(1, len(sorted_list) + 1))}

# %%
mapped_dict
# Out:
# {'ACO': 1,
#  'AEI': 2,
#  'AEL': 3,
#  'AEN': 4,
#  'AET': 5,
#  'AFG': 6,
#  'AFI': 7,
#  'AFN': 8,
#  'AFO': 9,
#  'AFR': 10,
#  'AFS': 11,
#  'AFT': 12,
#  'AFV': 13,
#  'AFX': 14,
#  'AFY': 15,
#  'AHT': 16,
#  'ANO': 17,
#  'APC': 18,
#  'APD': 19,
#  'AST': 20,
#  'ASV': 21,
#  'ATN': 22,
#  'ATO': 23,
#  'ATS': 24,
#  'ATT': 25,
#  'ATV': 26,
#  'AVE': 27,
#  'AVL': 28,
#  'AWO': 29,
#  'AWW': 30,
#  'BCT': 31,
#  'BIK': 32,
#  'BOF': 33,
#  'BOG': 34,
#  'BOZ': 35,
#  'BPH': 36,
#  'BRE': 37,
#  'BSV': 38,
#  'CAN': 39,
#  'CAS': 40,
#  'CDO': 41,
#  'CFI': 42,
#  'CGF': 43,
#  'CGS': 44,
#  'CON': 45,
#  'CSV': 46,
#  'CZP': 47,
#  'DAC': 48,
#  'DFO': 49,
#  'DFT': 50,
#  'DOH': 51,
#  'DON': 52,
#  'EAB': 53,
#  'EEI': 54,
#  'EMT': 55,
#  'EON': 56,
#  'EOS': 57,
#  'EPI': 58,
#  'ESV': 59,
#  'ETL': 60,
#  'ETR': 61,
#  'ETV': 62,
#  'EUO': 63,
#  'EWF': 64,
#  'EWO': 65,
#  'EWS': 66,
#  'EZT': 67,
#  'FAR': 68,
#  'FRA': 69,
#  'GIS': 70,
#  'GIU': 71,
#  'GME': 72,
#  'GON': 73,
#  'GOO': 74,
#  'IFO': 75,
#  'IFR': 76,
#  'IFW': 77,
#  'IFY': 78,
#  'IHW': 79,
#  'IRN': 80,
#  'IRR': 81,
#  'ISV': 82,
#  'ITE': 83,
#  'ITG': 84,
#  'ITH': 85,
#  'ITR': 86,
#  'ITT': 87,
#  'ITW': 88,
#  'IWR': 89,
#  'IWS': 90,
#  'IWV': 91,
#  'IWW': 92,
#  'JNT': 93,
#  'JOZ': 94,
#  'JRY': 95,
#  'JSN': 96,
#  'JSR': 97,
#  'JST': 98,
#  'JSW': 99,
#  'JSY': 100,
#  'JZT': 101,
#  'KFI': 102,
#  'LAU': 103,
#  'LEV': 104,
#  'LIO': 105,
#  'LOS': 106,
#  'LOV': 107,
#  'LTF': 108,
#  'LTJ': 109,
#  'MAR': 110,
#  'MAZ': 111,
#  'MEI': 112,
#  'MEP': 113,
#  'MFS': 114,
#  'MON': 115,
#  'MOZ': 116,
#  'MRT': 117,
#  'MSE': 118,
#  'MSO': 119,
#  'MTF': 120,
#  'MTN': 121,
#  'MTT': 122,
#  'MVY': 123,
#  'MWW': 124,
#  'NAB': 125,
#  'NES': 126,
#  'NON': 127,
#  'NPT': 128,
#  'NSI': 129,
#  'OBW': 130,
#  'OFF': 131,
#  'OKO': 132,
#  'OSI': 133,
#  'OSO': 134,
#  'OWE': 135,
#  'PCR': 136,
#  'PHI': 137,
#  'PON': 138,
#  'POR': 139,
#  'POS': 140,
#  'PSI': 141,
#  'PTF': 142,
#  'PTO': 143,
#  'PTT': 144,
#  'PTY': 145,
#  'PWW': 146,
#  'RFE': 147,
#  'RRO': 148,
#  'RTE': 149,
#  'RTH': 150,
#  'RUT': 151,
#  'RWR': 152,
#  'RWY': 153,
#  'SAF': 154,
#  'SAO': 155,
#  'SAS': 156,
#  'SAT': 157,
#  'SAV': 158,
#  'SBE': 159,
#  'SBN': 160,
#  'SBS': 161,
#  'SBT': 162,
#  'SEW': 163,
#  'SFE': 164,
#  'SFF': 165,
#  'SFG': 166,
#  'SFH': 167,
#  'SFN': 168,
#  'SFO': 169,
#  'SFS': 170,
#  'SFW': 171,
#  'SGT': 172,
#  'SIV': 173,
#  'SOD': 174,
#  'SOF': 175,
#  'SOR': 176,
#  'SOS': 177,
#  'SOV': 178,
#  'SSF': 179,
#  'SSY': 180,
#  'STF': 181,
#  'STI': 182,
#  'STT': 183,
#  'STW': 184,
#  'SVV': 185,
#  'SWY': 186,
#  'SZR': 187,
#  'TER': 188,
#  'THO': 189,
#  'TOL': 190,
#  'TUN': 191,
#  'UEI': 192,
#  'UFI': 193,
#  'UOS': 194,
#  'UOV': 195,
#  'UOZ': 196,
#  'USI': 197,
#  'UTL': 198,
#  'UWY': 199,
#  'VET': 200,
#  'VFI': 201,
#  'VNI': 202,
#  'VSV': 203,
#  'WEI': 204,
#  'YUG': 205,
#  'ZON': 206}
